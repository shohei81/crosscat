# %%
import jax
from jax import jit
import jax.numpy as jnp
import genjax
from genjax import gen
import equinox as eq
from genjax import inverse_gamma, normal, categorical, smc, Target
from tensorflow_probability.substrates import jax as tfp

from genjax import ChoiceMapBuilder as C
from genjax import Pytree, Weight, gen, pretty
from genjax._src.generative_functions.distributions.distribution import Distribution
from genjax.typing import PRNGKey
from jaxtyping import Array, Float, Integer
import time


tfd = tfp.distributions
key = jax.random.PRNGKey(0)
pretty()
# Out:
# 2024-10-09 18:25:31.194699: W external/xla/xla/service/gpu/nvptx_compiler.cc:893] The NVIDIA driver's CUDA version is 12.2 which is older than the PTX compiler version 12.6.68. Because the driver is older than the PTX compiler version, XLA is disabling parallel compilation, which may slow down compilation. You should update your NVIDIA driver or use the NVIDIA-provided CUDA forward compatibility packages.

# %%
@Pytree.dataclass
class NormalInverseGamma(Distribution):
    def random_weighted(self, key: PRNGKey, mu, l, a, b):
        ig = tfd.InverseGamma(concentration=a, scale=b)
        key, subkey = jax.random.split(key)
        precision = ig.sample(seed=subkey)
        ig_logp = ig.log_prob(precision)

        normal = tfd.Normal(loc=mu, scale=precision / l)
        key, subkey = jax.random.split(key)
        mu = normal.sample(seed=subkey)
        mu_logp = normal.log_prob(mu)
        
        retval = jnp.stack([mu, precision], axis=1)
        inv_logp = -jnp.sum(ig_logp) - jnp.sum(mu_logp)
        return inv_logp, retval

    def estimate_logpdf(self, key: PRNGKey, x, mu, l, a, b):
        mu_sampled = x[:,0]
        precision = x[:,1]
        ig = tfd.InverseGamma(concentration=a, scale=b)
        ig_logp = ig.log_prob(precision)
        normal = tfd.Normal(loc=mu, scale= precision/l)
        mu_logp = normal.log_prob(mu_sampled)
        return jnp.sum(ig_logp) + jnp.sum(mu_logp)

nig = NormalInverseGamma()

@gen
def model():
    x = nig(jnp.zeros(10), jnp.ones(10), jnp.ones(10), jnp.ones(10)) @ "x"
    return x

model.simulate(key, ())
# Out:
# <script> (()=>{ if (customElements.get('treescope-container') === undefined) { class TreescopeContainer extends HTMLElement { constructor() { super(); this.attachShadow({mode: "open"}); this.defns = {}; this.state = {}; } } customElements.define("treescope-container", TreescopeContainer); } if (customElements.get('treescope-run-here') === undefined) { class RunHere extends HTMLElement { constructor() { super() } connectedCallback() { const run = child => { const fn = new Function(child.textContent); child.textContent = ""; fn.call(this); this.remove(); }; const child = this.querySelector("script"); if (child) { run(child); } else { new MutationObserver(()=>{ run(this.querySelector("script")); }).observe(this, {childList: true}); } } } customElements.define("treescope-run-here", RunHere); } })(); </script> <treescope-container class="treescope_out_3efc1196482b45b595a9b3b8d1377b2e" ></treescope-container> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_3efc1196482b45b595a9b3b8d1377b2e")) .filter((elt) => !elt.dataset.setup) )[0]; root.dataset.setup = 1; const msg = document.createElement("span"); msg.style = "color: #aaaaaa; font-family: monospace; transition: opacity 0.2s; opacity: 0.0;"; msg.textContent = "(Loading...)"; root.state.loadingMsg = msg; root.shadowRoot.appendChild(msg); root.state.chain = new Promise((resolve, reject) => { const observer = new IntersectionObserver((entries) => { for (const entry of entries) { if (entry.isIntersecting) { resolve(); observer.disconnect(); return; } } }, {rootMargin: "1000px"}); window.setTimeout(() => { if (root.loadingMsg) { root.loadingMsg.style.opacity = "1.0"; } observer.observe(root); }, 0); }); root.state.deferring = false; const _insertNode = (node) => { for (let oldScript of node.querySelectorAll("script")) { let newScript = document.createElement("script"); newScript.type = oldScript.type; newScript.textContent = oldScript.textContent; oldScript.parentNode.replaceChild(newScript, oldScript); } if (root.state.loadingMsg) { root.state.loadingMsg.remove(); root.state.loadingMsg = null; } root.shadowRoot.appendChild(node); }; root.defns.insertContent = ((contentNode, compressed) => { if (compressed) { root.state.deferring = true; } if (root.state.deferring) { root.state.chain = (async () => { await root.state.chain; if (compressed) { const encoded = contentNode.textContent; const blob = new Blob([ Uint8Array.from(atob(encoded), (m) => m.codePointAt(0)) ]); const reader = blob.stream().pipeThrough( new DecompressionStream("deflate") ).pipeThrough( new TextDecoderStream("utf-8") ).getReader(); const parts = []; while (true) { const step = await reader.read(); if (step.done) { break; } parts.push(step.value); } const tpl = document.createElement('template'); tpl.innerHTML = parts.join(""); _insertNode(tpl.content); } else { _insertNode(contentNode.content); } })(); } else { _insertNode(contentNode.content); } }); </script></treescope-run-here><div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_3efc1196482b45b595a9b3b8d1377b2e")) .filter((elt) => !elt.dataset['step0']) )[0]; root.dataset['step0'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# <div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_3efc1196482b45b595a9b3b8d1377b2e")) .filter((elt) => !elt.dataset['step1']) )[0]; root.dataset['step1'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# StaticTrace(...)

# %%
@Pytree.dataclass
class Dirichlet(Distribution):
    def random_weighted(self, key:PRNGKey, alpha):
        dir = tfd.Dirichlet(concentration = alpha)
        probs = dir.sample(seed=key)
        inv_weight = -dir.log_prob(probs)
        return inv_weight, probs
    def estimate_logpdf(self, key:PRNGKey, x, alpha):
        dir = tfd.Dirichlet(concentration = alpha)
        return dir.log_prob(x)
dirichlet = Dirichlet()

@gen
def model():
    dist = dirichlet(jnp.ones((5,5))) @ "x"
    return dist

tr = model.simulate(key, ())

# %%
"""
A class to store DP samples and the corresponding beta values. 

Used in GEM to avoid floating point error
"""
@Pytree.dataclass
class DPSample(Pytree):
    betas: Array
    pi: Array
    def __init__(self, betas, pi):
        self.betas = betas
        self.pi = pi

# %%
def log1mexp(x):
    return jnp.where(-jnp.log(2) < x, jnp.log(-jnp.expm1(x)), jnp.log1p(-jnp.exp(x)))

print(-jnp.log(2))
a = jnp.array(-0.03244329398193646)
print(log1mexp(a))
print(jnp.log(1-jnp.exp(a)))
# Out:
# -0.6931472
# -3.4444394
# -3.44444

# %%
@Pytree.dataclass
class GEM(Distribution):
    C: int = Pytree.static(default=1)
    def __init__(self, C:int=10):
        self.C = jnp.asarray(C)
    def random_weighted(self, key: PRNGKey, alpha: Float):
        C = self.C
        sampler = tfd.Beta(concentration1 = jnp.array(alpha), concentration0=jnp.array(1.0))
        betas = sampler.sample(seed=key, sample_shape = C)
        inv_weight = -jnp.sum(sampler.log_prob(betas))

        betas = jnp.log(betas)
        betas_not = jax.vmap(log1mexp)(betas)
        print("betas ", betas)
        # prefix sum of betas
        logpi = jnp.zeros(C)
        for i in range(1,C):
            logpi = logpi.at[i].set(jnp.sum(betas_not[:i]))
        for i in range(C):
            logpi = logpi.at[i].set(logpi[i] + betas[i])

        return inv_weight, logpi

    def estimate_logpdf(self, key: PRNGKey, pi, alpha: Float):
        # assumes dist.pi corresponds to dist.betas
        sampler = tfd.Beta(concentration1 = jnp.array(alpha), concentration0 = jnp.array(1.0))
        def unfold(carry, pi):
            logbeta = pi - carry
            return carry + log1mexp(logbeta), logbeta

        _, betas = jax.lax.scan(unfold, 0.0, pi)
        print("betas ", betas)
        betas = jnp.exp(betas)
        weight = jnp.sum(sampler.log_prob(betas))
        return weight

gem = GEM(10)

@gen
def model():
    pi = gem(jnp.array(2.0)) @ "pi"
    return pi

# jax.jit(model.simulate)(key, ())
_, key = jax.random.split(key)
tr = model.simulate(key, ())
print("pi ", tr.retval)

print(gem.estimate_logpdf(key, tr.retval, jnp.array(2.0), ))
# Out:
# betas  Traced<ShapedArray(float32[10])>with<DynamicJaxprTrace(level=2/0)>
# betas  [-0.59842694 -0.18138668 -0.49231285 -0.07199378 -0.8898936  -0.10840753
#  -0.1964778  -0.04370651 -0.07381264 -1.4512422 ]
# pi  [ -0.59842694  -0.9791739   -3.0865471   -3.610947    -7.0958033
#   -6.8431363   -9.206779   -10.777844   -13.959982   -17.980316  ]
# betas  [-0.59842694 -0.18138671 -0.49231315 -0.07199454 -0.889905   -0.10842705
#  -0.19666767 -0.04477119 -0.09841633 -1.7513981 ]
# 2.497777

# %%
tr
# Out:
# <script> (()=>{ if (customElements.get('treescope-container') === undefined) { class TreescopeContainer extends HTMLElement { constructor() { super(); this.attachShadow({mode: "open"}); this.defns = {}; this.state = {}; } } customElements.define("treescope-container", TreescopeContainer); } if (customElements.get('treescope-run-here') === undefined) { class RunHere extends HTMLElement { constructor() { super() } connectedCallback() { const run = child => { const fn = new Function(child.textContent); child.textContent = ""; fn.call(this); this.remove(); }; const child = this.querySelector("script"); if (child) { run(child); } else { new MutationObserver(()=>{ run(this.querySelector("script")); }).observe(this, {childList: true}); } } } customElements.define("treescope-run-here", RunHere); } })(); </script> <treescope-container class="treescope_out_cb76600ac3a845298b98743af79ec092" ></treescope-container> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_cb76600ac3a845298b98743af79ec092")) .filter((elt) => !elt.dataset.setup) )[0]; root.dataset.setup = 1; const msg = document.createElement("span"); msg.style = "color: #aaaaaa; font-family: monospace; transition: opacity 0.2s; opacity: 0.0;"; msg.textContent = "(Loading...)"; root.state.loadingMsg = msg; root.shadowRoot.appendChild(msg); root.state.chain = new Promise((resolve, reject) => { const observer = new IntersectionObserver((entries) => { for (const entry of entries) { if (entry.isIntersecting) { resolve(); observer.disconnect(); return; } } }, {rootMargin: "1000px"}); window.setTimeout(() => { if (root.loadingMsg) { root.loadingMsg.style.opacity = "1.0"; } observer.observe(root); }, 0); }); root.state.deferring = false; const _insertNode = (node) => { for (let oldScript of node.querySelectorAll("script")) { let newScript = document.createElement("script"); newScript.type = oldScript.type; newScript.textContent = oldScript.textContent; oldScript.parentNode.replaceChild(newScript, oldScript); } if (root.state.loadingMsg) { root.state.loadingMsg.remove(); root.state.loadingMsg = null; } root.shadowRoot.appendChild(node); }; root.defns.insertContent = ((contentNode, compressed) => { if (compressed) { root.state.deferring = true; } if (root.state.deferring) { root.state.chain = (async () => { await root.state.chain; if (compressed) { const encoded = contentNode.textContent; const blob = new Blob([ Uint8Array.from(atob(encoded), (m) => m.codePointAt(0)) ]); const reader = blob.stream().pipeThrough( new DecompressionStream("deflate") ).pipeThrough( new TextDecoderStream("utf-8") ).getReader(); const parts = []; while (true) { const step = await reader.read(); if (step.done) { break; } parts.push(step.value); } const tpl = document.createElement('template'); tpl.innerHTML = parts.join(""); _insertNode(tpl.content); } else { _insertNode(contentNode.content); } })(); } else { _insertNode(contentNode.content); } }); </script></treescope-run-here><div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_cb76600ac3a845298b98743af79ec092")) .filter((elt) => !elt.dataset['step0']) )[0]; root.dataset['step0'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# <div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_cb76600ac3a845298b98743af79ec092")) .filter((elt) => !elt.dataset['step1']) )[0]; root.dataset['step1'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# StaticTrace(...)

# %%
@gen
def model():
    pi = gem(jnp.array(2.0)) @ "pi"
    return pi

simulate_jitted = jax.jit(jax.vmap(model.simulate, in_axes=(0,None)))
keys = jax.random.split(key, 1000)
simulate_jitted(keys, ())
# Out:
# <script> (()=>{ if (customElements.get('treescope-container') === undefined) { class TreescopeContainer extends HTMLElement { constructor() { super(); this.attachShadow({mode: "open"}); this.defns = {}; this.state = {}; } } customElements.define("treescope-container", TreescopeContainer); } if (customElements.get('treescope-run-here') === undefined) { class RunHere extends HTMLElement { constructor() { super() } connectedCallback() { const run = child => { const fn = new Function(child.textContent); child.textContent = ""; fn.call(this); this.remove(); }; const child = this.querySelector("script"); if (child) { run(child); } else { new MutationObserver(()=>{ run(this.querySelector("script")); }).observe(this, {childList: true}); } } } customElements.define("treescope-run-here", RunHere); } })(); </script> <treescope-container class="treescope_out_287505b9920044769f8aa048902776cf" ></treescope-container> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_287505b9920044769f8aa048902776cf")) .filter((elt) => !elt.dataset.setup) )[0]; root.dataset.setup = 1; const msg = document.createElement("span"); msg.style = "color: #aaaaaa; font-family: monospace; transition: opacity 0.2s; opacity: 0.0;"; msg.textContent = "(Loading...)"; root.state.loadingMsg = msg; root.shadowRoot.appendChild(msg); root.state.chain = new Promise((resolve, reject) => { const observer = new IntersectionObserver((entries) => { for (const entry of entries) { if (entry.isIntersecting) { resolve(); observer.disconnect(); return; } } }, {rootMargin: "1000px"}); window.setTimeout(() => { if (root.loadingMsg) { root.loadingMsg.style.opacity = "1.0"; } observer.observe(root); }, 0); }); root.state.deferring = false; const _insertNode = (node) => { for (let oldScript of node.querySelectorAll("script")) { let newScript = document.createElement("script"); newScript.type = oldScript.type; newScript.textContent = oldScript.textContent; oldScript.parentNode.replaceChild(newScript, oldScript); } if (root.state.loadingMsg) { root.state.loadingMsg.remove(); root.state.loadingMsg = null; } root.shadowRoot.appendChild(node); }; root.defns.insertContent = ((contentNode, compressed) => { if (compressed) { root.state.deferring = true; } if (root.state.deferring) { root.state.chain = (async () => { await root.state.chain; if (compressed) { const encoded = contentNode.textContent; const blob = new Blob([ Uint8Array.from(atob(encoded), (m) => m.codePointAt(0)) ]); const reader = blob.stream().pipeThrough( new DecompressionStream("deflate") ).pipeThrough( new TextDecoderStream("utf-8") ).getReader(); const parts = []; while (true) { const step = await reader.read(); if (step.done) { break; } parts.push(step.value); } const tpl = document.createElement('template'); tpl.innerHTML = parts.join(""); _insertNode(tpl.content); } else { _insertNode(contentNode.content); } })(); } else { _insertNode(contentNode.content); } }); </script></treescope-run-here><div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_287505b9920044769f8aa048902776cf")) .filter((elt) => !elt.dataset['step0']) )[0]; root.dataset['step0'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# <div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_287505b9920044769f8aa048902776cf")) .filter((elt) => !elt.dataset['step1']) )[0]; root.dataset['step1'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# StaticTrace(...)

# %%
# @Pytree.dataclass
# class GemByDirichlet(Distribution):
#     C: int = Pytree.static(default=1)
#     def __init__(self, C:int=10):
#         self.C = jnp.asarray(C)
#     def random_weighted(self, key: PRNGKey, concentration):
#         dir = tfd.Dirichlet(concentration=concentration)
#         probs = dir.sample(seed=key)
#         # invert betas
#         def unfold(carry, x):
#             beta = x / carry
#             return carry * (1-beta) , carry * beta
#         _, betas = jax.lax.scan(unfold, jnp.array(1.0), probs)
#         x = DPSample(betas, probs)
#         inv_weight = -dir.log_prob(probs)
#         return inv_weight, x

#     def estimate_logpdf(self, key: PRNGKey, x:DPSample, concentration):
#         # assumes dist.pi corresponds to dist.betas
#         dir = tfd.Dirichlet(concentration = concentration)
#         return dir.log_prob(x.pi)

# gbd = GemByDirichlet(10)
# @gen
# def model():
#     pi = gbd(jnp.ones((10,))) @ "pi"
#     return pi

# model.simulate(key, ())

# %%
@Pytree.dataclass
class MixtureModel(Distribution):
    def random_weighted(self, key, pi, categorical_probs):
        key_0, key_1 = jax.random.split(key, 2)
        cluster_dist = tfd.Categorical(pi)
        c = cluster_dist.sample(seed=key_0)
        c_logp = cluster_dist.log_prob(c)
        label_dist = tfd.Categorical(categorical_probs[c])
        y = label_dist.sample(seed=key_1)
        y_logp = label_dist.log_prob(y)
        return -c_logp-y_logp, (c,y)

    def estimate_logpdf(self, key:PRNGKey, x, pi, categorical_probs):
        c, y = x
        cluster_dist = tfd.Categorical(pi)
        label_dist = tfd.Categorical(categorical_probs[c])
        logp = cluster_dist.log_prob(c) + label_dist.log_prob(y)
        return logp

cmm = MixtureModel()

@genjax.repeat(n=100)
@gen 
def cluster(pi, probs):
    assignments = cmm(pi, probs) @ "assignments"
    return assignments

pi = jnp.ones(10) / 10
categorical_probs = jax.random.uniform(key, (10, 36, 19))
tr = cluster.simulate(key, (pi, categorical_probs,))
tr.get_choices()[0, "assignments"].unmask()
# Out:
# <script> (()=>{ if (customElements.get('treescope-container') === undefined) { class TreescopeContainer extends HTMLElement { constructor() { super(); this.attachShadow({mode: "open"}); this.defns = {}; this.state = {}; } } customElements.define("treescope-container", TreescopeContainer); } if (customElements.get('treescope-run-here') === undefined) { class RunHere extends HTMLElement { constructor() { super() } connectedCallback() { const run = child => { const fn = new Function(child.textContent); child.textContent = ""; fn.call(this); this.remove(); }; const child = this.querySelector("script"); if (child) { run(child); } else { new MutationObserver(()=>{ run(this.querySelector("script")); }).observe(this, {childList: true}); } } } customElements.define("treescope-run-here", RunHere); } })(); </script> <treescope-container class="treescope_out_83a221baea07439fad452e7b7b28783a" ></treescope-container> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_83a221baea07439fad452e7b7b28783a")) .filter((elt) => !elt.dataset.setup) )[0]; root.dataset.setup = 1; const msg = document.createElement("span"); msg.style = "color: #aaaaaa; font-family: monospace; transition: opacity 0.2s; opacity: 0.0;"; msg.textContent = "(Loading...)"; root.state.loadingMsg = msg; root.shadowRoot.appendChild(msg); root.state.chain = new Promise((resolve, reject) => { const observer = new IntersectionObserver((entries) => { for (const entry of entries) { if (entry.isIntersecting) { resolve(); observer.disconnect(); return; } } }, {rootMargin: "1000px"}); window.setTimeout(() => { if (root.loadingMsg) { root.loadingMsg.style.opacity = "1.0"; } observer.observe(root); }, 0); }); root.state.deferring = false; const _insertNode = (node) => { for (let oldScript of node.querySelectorAll("script")) { let newScript = document.createElement("script"); newScript.type = oldScript.type; newScript.textContent = oldScript.textContent; oldScript.parentNode.replaceChild(newScript, oldScript); } if (root.state.loadingMsg) { root.state.loadingMsg.remove(); root.state.loadingMsg = null; } root.shadowRoot.appendChild(node); }; root.defns.insertContent = ((contentNode, compressed) => { if (compressed) { root.state.deferring = true; } if (root.state.deferring) { root.state.chain = (async () => { await root.state.chain; if (compressed) { const encoded = contentNode.textContent; const blob = new Blob([ Uint8Array.from(atob(encoded), (m) => m.codePointAt(0)) ]); const reader = blob.stream().pipeThrough( new DecompressionStream("deflate") ).pipeThrough( new TextDecoderStream("utf-8") ).getReader(); const parts = []; while (true) { const step = await reader.read(); if (step.done) { break; } parts.push(step.value); } const tpl = document.createElement('template'); tpl.innerHTML = parts.join(""); _insertNode(tpl.content); } else { _insertNode(contentNode.content); } })(); } else { _insertNode(contentNode.content); } }); </script></treescope-run-here><div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_83a221baea07439fad452e7b7b28783a")) .filter((elt) => !elt.dataset['step0']) )[0]; root.dataset['step0'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# <div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_83a221baea07439fad452e7b7b28783a")) .filter((elt) => !elt.dataset['step1']) )[0]; root.dataset['step1'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# (<jax.Array(7, dtype=int32)>,
#  <jax.Array int32(36,) [≥0, ≤17] zero:1 nonzero:35
#    <Arrayviz rendering>
#  >)

# %%
@genjax.repeat(n=100)
@gen 
def cluster(pi, probs):
    assignments = cmm(pi, probs) @ "assignments"
    return assignments

@gen
def model(data):
    C = 20
    n_features = data.shape[0]
    n_labels = 20
    pi = gem(jnp.array(2.0)) @ "pi"
    cluster_parameters = dirichlet(jnp.ones((C, n_features, n_labels))) @ "parameters"
    assignments = cluster(pi, cluster_parameters) @ "assignments"
    return assignments

simulate_jitted = jax.jit(model.simulate)
data = jax.random.uniform(key, (100, 36), minval=0, maxval=19)
simulate_jitted(key, (data,))
# Out:
# <script> (()=>{ if (customElements.get('treescope-container') === undefined) { class TreescopeContainer extends HTMLElement { constructor() { super(); this.attachShadow({mode: "open"}); this.defns = {}; this.state = {}; } } customElements.define("treescope-container", TreescopeContainer); } if (customElements.get('treescope-run-here') === undefined) { class RunHere extends HTMLElement { constructor() { super() } connectedCallback() { const run = child => { const fn = new Function(child.textContent); child.textContent = ""; fn.call(this); this.remove(); }; const child = this.querySelector("script"); if (child) { run(child); } else { new MutationObserver(()=>{ run(this.querySelector("script")); }).observe(this, {childList: true}); } } } customElements.define("treescope-run-here", RunHere); } })(); </script> <treescope-container class="treescope_out_85fed2ed5cf2451b8db09430c749fbcf" ></treescope-container> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_85fed2ed5cf2451b8db09430c749fbcf")) .filter((elt) => !elt.dataset.setup) )[0]; root.dataset.setup = 1; const msg = document.createElement("span"); msg.style = "color: #aaaaaa; font-family: monospace; transition: opacity 0.2s; opacity: 0.0;"; msg.textContent = "(Loading...)"; root.state.loadingMsg = msg; root.shadowRoot.appendChild(msg); root.state.chain = new Promise((resolve, reject) => { const observer = new IntersectionObserver((entries) => { for (const entry of entries) { if (entry.isIntersecting) { resolve(); observer.disconnect(); return; } } }, {rootMargin: "1000px"}); window.setTimeout(() => { if (root.loadingMsg) { root.loadingMsg.style.opacity = "1.0"; } observer.observe(root); }, 0); }); root.state.deferring = false; const _insertNode = (node) => { for (let oldScript of node.querySelectorAll("script")) { let newScript = document.createElement("script"); newScript.type = oldScript.type; newScript.textContent = oldScript.textContent; oldScript.parentNode.replaceChild(newScript, oldScript); } if (root.state.loadingMsg) { root.state.loadingMsg.remove(); root.state.loadingMsg = null; } root.shadowRoot.appendChild(node); }; root.defns.insertContent = ((contentNode, compressed) => { if (compressed) { root.state.deferring = true; } if (root.state.deferring) { root.state.chain = (async () => { await root.state.chain; if (compressed) { const encoded = contentNode.textContent; const blob = new Blob([ Uint8Array.from(atob(encoded), (m) => m.codePointAt(0)) ]); const reader = blob.stream().pipeThrough( new DecompressionStream("deflate") ).pipeThrough( new TextDecoderStream("utf-8") ).getReader(); const parts = []; while (true) { const step = await reader.read(); if (step.done) { break; } parts.push(step.value); } const tpl = document.createElement('template'); tpl.innerHTML = parts.join(""); _insertNode(tpl.content); } else { _insertNode(contentNode.content); } })(); } else { _insertNode(contentNode.content); } }); </script></treescope-run-here><div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_85fed2ed5cf2451b8db09430c749fbcf")) .filter((elt) => !elt.dataset['step0']) )[0]; root.dataset['step0'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# <div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_85fed2ed5cf2451b8db09430c749fbcf")) .filter((elt) => !elt.dataset['step1']) )[0]; root.dataset['step1'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# StaticTrace(...)

# %%
tr = simulate_jitted(key, ())
tr.get_choices()["assignments", 0, "assignments"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 tr = simulate_jitted(key, ())
#       2 tr.get_choices()["assignments", 0, "assignments"]
#
#     [... skipping hidden 11 frame]
#
# File <@beartype(genjax._src.generative_functions.static.StaticGenerativeFunction.simulate) at 0x737bb3acce50>:55, in simulate(__beartype_object_126975544417216, __beartype_get_violation, __beartype_conf, __beartype_object_100220940444160, __beartype_func, *args, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/generative_functions/static.py:522, in StaticGenerativeFunction.simulate(self, key, args)
#     514 def simulate(
#     515     self,
#     516     key: PRNGKey,
#     517     args: tuple[Any, ...],
#     518 ) -> StaticTrace[R]:
#     519     syntax_sugar_handled = push_trace_overload_stack(
#     520         handler_trace_with_static, self.source
#     521     )
# --> 522     (args, retval, address_visitor, address_traces, score) = simulate_transform(
#     523         syntax_sugar_handled
#     524     )(key, args)
#     525     return StaticTrace(
#     526         self,
#     527         args,
#    (...)
#     531         score,
#     532     )
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/generative_functions/static.py:268, in simulate_transform.<locals>.wrapper(key, args)
#     265 @functools.wraps(source_fn)
#     266 def wrapper(key, args):
#     267     stateful_handler = SimulateHandler(key)
# --> 268     retval = forward(source_fn)(stateful_handler, *args)
#     269     (
#     270         address_visitor,
#     271         address_traces,
#     272         score,
#     273     ) = stateful_handler.yield_state()
#     274     return (
#     275         args,
#     276         retval,
#    (...)
#     279         score,
#     280     )
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/core/interpreters/forward.py:250, in wrapped(stateful_handler, *args)
#     247 @functools.wraps(f)
#     248 def wrapped(stateful_handler: StatefulHandler, *args):
#     249     interpreter = ForwardInterpreter()
# --> 250     return interpreter.run_interpreter(
#     251         stateful_handler,
#     252         f,
#     253         *args,
#     254     )
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/core/interpreters/forward.py:235, in ForwardInterpreter.run_interpreter(self, stateful_handler, fn, *args, **kwargs)
#     232 def _inner(*args):
#     233     return fn(*args, **kwargs)
# --> 235 _closed_jaxpr, (flat_args, _, out_tree) = stage(_inner)(*args)
#     236 _jaxpr, consts = _closed_jaxpr.jaxpr, _closed_jaxpr.literals
#     237 flat_out = self._eval_jaxpr_forward(
#     238     stateful_handler,
#     239     _jaxpr,
#     240     consts,
#     241     flat_args,
#     242 )
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/core/interpreters/staging.py:190, in stage.<locals>.wrapped(*args, **kwargs)
#     188 flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
#     189 flat_avals = safe_map(get_shaped_aval, flat_args)
# --> 190 typed_jaxpr = cached_stage_dynamic(flat_fun, tuple(flat_avals))
#     191 return typed_jaxpr, (flat_args, in_tree, out_tree)
#
#     [... skipping hidden 1 frame]
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/core/interpreters/staging.py:164, in cached_stage_dynamic(flat_fun, in_avals)
#     162 @lu.cache
#     163 def cached_stage_dynamic(flat_fun, in_avals):
# --> 164     jaxpr, _, consts = pe.trace_to_jaxpr_dynamic(flat_fun, in_avals)
#     165     typed_jaxpr = jc.ClosedJaxpr(jaxpr, consts)
#     166     return typed_jaxpr
#
#     [... skipping hidden 5 frame]
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/core/interpreters/forward.py:233, in ForwardInterpreter.run_interpreter.<locals>._inner(*args)
#     232 def _inner(*args):
# --> 233     return fn(*args, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/core/generative/core.py:1513, in push_trace_overload_stack.<locals>.wrapped(*args)
#    1511 def wrapped(*args):
#    1512     GLOBAL_TRACE_OP_HANDLER_STACK.append(handler)
# -> 1513     ret = fn(*args)
#    1514     GLOBAL_TRACE_OP_HANDLER_STACK.pop()
#    1515     return ret
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/core/pytree.py:403, in Closure.__call__(self, *args, **kwargs)
#     402 def __call__(self, *args, **kwargs) -> R:
# --> 403     return self.fn(*self.dyn_args, *args, **kwargs)
#
# TypeError: model() missing 1 required positional argument: 'data'

# %% [markdown]
# ### Inference?

# %%
from genjax import ChoiceMapBuilder as C
import genspn.distributions 

key = jax.random.PRNGKey(0)
obs = C["assignments",0,"assignments"].set((jnp.array(2, dtype=jnp.int32), jnp.zeros((36,), dtype=jnp.int32)))
obs = tr.get_choices()
args = ()
model.importance(key, obs, args)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[360], line 8
#       6 obs = tr.get_choices()
#       7 args = ()
# ----> 8 model.importance(key, obs, args)
#
# File <@beartype(genjax._src.core.generative.core.GenerativeFunction.importance) at 0x73a54827c160>:76, in importance(__beartype_object_127153717298432, __beartype_get_violation, __beartype_conf, __beartype_object_97727395841744, __beartype_object_97727395876784, __beartype_object_97727394042224, __beartype_func, *args, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/core/generative/core.py:749, in GenerativeFunction.importance(self, key, constraint, args)
#     708 def importance(
#     709     self,
#     710     key: PRNGKey,
#     711     constraint: Constraint,
#     712     args: Arguments,
#     713 ) -> tuple[Trace[R], Weight]:
#     714     """
#     715     Returns a properly weighted pair, a [`Trace`][genjax.core.Trace] and a [`Weight`][genjax.core.Weight], properly weighted for the target induced by the generative function for the provided constraint and arguments.
#     716
#    (...)
#     747     Under the hood, creates an [`UpdateProblem`][genjax.core.UpdateProblem] which requests that the generative function respond with a move from the _empty_ trace (the only possible value for _empty_ target $\\delta_\\emptyset$) to the target induced by the generative function for constraint $C$ with arguments $a$.
#     748     """
# --> 749     tr, w, _, _ = self.update(
#     750         key,
#     751         EmptyTrace(self),
#     752         GenericProblem(Diff.unknown_change(args), ImportanceProblem(constraint)),
#     753     )
#     754     return tr, w
#
# File <@beartype(genjax._src.generative_functions.static.StaticGenerativeFunction.update) at 0x73a52f97a290>:81, in update(__beartype_object_127153717298432, __beartype_get_violation, __beartype_conf, __beartype_object_97727395876784, __beartype_object_97727395848208, __beartype_object_97727404449280, __beartype_object_97727394042224, __beartype_object_127153717092720, __beartype_func, *args, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/generative_functions/static.py:588, in StaticGenerativeFunction.update(self, key, trace, update_problem)
#     586 match update_problem:
#     587     case GenericProblem(argdiffs, subproblem):
# --> 588         return self.update_change_target(key, trace, subproblem, argdiffs)
#     589     case _:
#     590         return self.update(
#     591             key,
#     592             trace,
#     593             GenericProblem(Diff.no_change(trace.get_args()), update_problem),
#     594         )
#
# File <@beartype(genjax._src.generative_functions.static.StaticGenerativeFunction.update_change_target) at 0x73a52f97a200>:106, in update_change_target(__beartype_object_127153717298432, __beartype_get_violation, __beartype_conf, __beartype_object_97727395876784, __beartype_object_97727395848208, __beartype_object_127153722494544, __beartype_object_97727404449280, __beartype_object_97727394042224, __beartype_object_127153717092720, __beartype_func, *args, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/generative_functions/static.py:557, in StaticGenerativeFunction.update_change_target(self, key, trace, update_problem, argdiffs)
#     534 def update_change_target(
#     535     self,
#     536     key: PRNGKey,
#    (...)
#     539     argdiffs: Argdiffs,
#     540 ) -> tuple[StaticTrace[R], Weight, Retdiff[R], UpdateProblem]:
#     541     syntax_sugar_handled = push_trace_overload_stack(
#     542         handler_trace_with_static, self.source
#     543     )
#     544     (
#     545         (
#     546             retval_diffs,
#     547             weight,
#     548             (
#     549                 arg_primals,
#     550                 retval_primals,
#     551                 address_visitor,
#     552                 address_traces,
#     553                 score,
#     554             ),
#     555             bwd_problems,
#     556         ),
# --> 557     ) = update_transform(syntax_sugar_handled)(key, trace, update_problem, argdiffs)
#     559     def make_bwd_problem(
#     560         visitor: AddressVisitor, subproblems: list[UpdateProblem]
#     561     ) -> ChoiceMap:
#     562         addresses = visitor.get_visited()
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/generative_functions/static.py:368, in wrapper(key, previous_trace, constraints, diffs)
#     366 diff_primals = Diff.tree_primal(diffs)
#     367 diff_tangents = Diff.tree_tangent(diffs)
# --> 368 retval_diffs = incremental(source_fn)(
#     369     stateful_handler, diff_primals, diff_tangents
#     370 )
#     371 retval_primals = Diff.tree_primal(retval_diffs)
#     372 (
#     373     score,
#     374     weight,
#    (...)
#     377     bwd_problems,
#     378 ) = stateful_handler.yield_state()
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/core/interpreters/incremental.py:278, in wrapped(_stateful_handler, primals, tangents)
#     271 @functools.wraps(f)
#     272 def wrapped(
#     273     _stateful_handler: StatefulHandler | None,
#     274     primals: tuple[Any, ...],
#     275     tangents: tuple[Any, ...],
#     276 ):
#     277     interpreter = IncrementalInterpreter()
# --> 278     return interpreter.run_interpreter(
#     279         _stateful_handler,
#     280         f,
#     281         primals,
#     282         tangents,
#     283     )
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/core/interpreters/incremental.py:260, in IncrementalInterpreter.run_interpreter(self, _stateful_handler, fn, primals, tangents, **kwargs)
#     256 flat_tangents = jtu.tree_leaves(
#     257     tangents, is_leaf=lambda v: isinstance(v, ChangeTangent)
#     258 )
#     259 _jaxpr, consts = _closed_jaxpr.jaxpr, _closed_jaxpr.literals
# --> 260 flat_out = self._eval_jaxpr_forward(
#     261     _stateful_handler,
#     262     _jaxpr,
#     263     consts,
#     264     flat_primals,
#     265     flat_tangents,
#     266 )
#     267 return jtu.tree_unflatten(out_tree(), flat_out)
#
# File <@beartype(genjax._src.core.interpreters.incremental.IncrementalInterpreter._eval_jaxpr_forward) at 0x73a548239a20>:101, in _eval_jaxpr_forward(__beartype_object_97727389641808, __beartype_get_violation, __beartype_conf, __beartype_object_97727395754528, __beartype_getrandbits, __beartype_func, *args, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/core/interpreters/incremental.py:242, in IncrementalInterpreter._eval_jaxpr_forward(self, _stateful_handler, _jaxpr, consts, primals, tangents)
#     240 args = subfuns + induals
#     241 if _stateful_handler and _stateful_handler.handles(_eqn.primitive):
# --> 242     outduals = _stateful_handler.dispatch(_eqn.primitive, *args, **_params)
#     243 else:
#     244     outduals = default_propagation_rule(_eqn.primitive, *args, **_params)
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/generative_functions/static.py:220, in StaticHandler.dispatch(self, primitive, *tracers, **_params)
#     218 addr = Pytree.tree_const_unwrap(addr)
#     219 if primitive == trace_p:
# --> 220     v = self.handle_trace(addr, gen_fn, args)
#     221     return self.handle_retval(v)
#     222 else:
#
# File <@beartype(genjax._src.generative_functions.static.UpdateHandler.handle_trace) at 0x73a52f978e50>:92, in handle_trace(__beartype_getrandbits, __beartype_get_violation, __beartype_conf, __beartype_object_97727395774320, __beartype_func, *args, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/generative_functions/static.py:351, in UpdateHandler.handle_trace(self, addr, gen_fn, args)
#     349 subproblem = self.get_subproblem(addr)
#     350 self.key, sub_key = jax.random.split(self.key)
# --> 351 (tr, w, retval_diff, bwd_problem) = gen_fn.update(
#     352     sub_key, subtrace, GenericProblem(argdiffs, subproblem)
#     353 )
#     354 self.score += tr.get_score()
#     355 self.weight += w
#
# File <@beartype(genjax._src.generative_functions.combinators.dimap.DimapCombinator.update) at 0x73a5482db490>:81, in update(__beartype_object_127153717298432, __beartype_get_violation, __beartype_conf, __beartype_object_97727395876784, __beartype_object_97727395848208, __beartype_object_97727396176128, __beartype_object_97727394042224, __beartype_object_127153717092720, __beartype_func, *args, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/generative_functions/combinators/dimap.py:181, in DimapCombinator.update(self, key, trace, update_problem)
#     179 match update_problem:
#     180     case GenericProblem(argdiffs, subproblem):
# --> 181         return self.update_change_target(key, trace, subproblem, argdiffs)
#     182     case _:
#     183         return self.update_change_target(
#     184             key, trace, update_problem, Diff.no_change(trace.get_args())
#     185         )
#
# File <@beartype(genjax._src.generative_functions.combinators.dimap.DimapCombinator.update_change_target) at 0x73a5482db400>:106, in update_change_target(__beartype_object_127153717298432, __beartype_get_violation, __beartype_conf, __beartype_object_97727395876784, __beartype_object_97727395848208, __beartype_object_127153722494544, __beartype_object_97727396176128, __beartype_object_97727394042224, __beartype_object_127153717092720, __beartype_func, *args, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/generative_functions/combinators/dimap.py:148, in DimapCombinator.update_change_target(self, key, trace, update_problem, argdiffs)
#     145     case EmptyTrace():
#     146         inner_trace = EmptyTrace(self.inner)
# --> 148 tr, w, inner_retdiff, bwd_problem = self.inner.update(
#     149     key, inner_trace, GenericProblem(inner_argdiffs, update_problem)
#     150 )
#     152 inner_retval_primals = Diff.tree_primal(inner_retdiff)
#     153 inner_retval_tangents = Diff.tree_tangent(inner_retdiff)
#
# File <@beartype(genjax._src.generative_functions.combinators.vmap.VmapCombinator.update) at 0x73a52f9a6cb0>:81, in update(__beartype_object_127153717298432, __beartype_get_violation, __beartype_conf, __beartype_object_97727395876784, __beartype_object_97727395848208, __beartype_object_97727405793760, __beartype_object_97727394042224, __beartype_object_127153717092720, __beartype_func, *args, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/generative_functions/combinators/vmap.py:268, in VmapCombinator.update(self, key, trace, update_problem)
#     266 match update_problem:
#     267     case GenericProblem(argdiffs, subproblem):
# --> 268         return self.update_change_target(key, trace, subproblem, argdiffs)
#     269     case _:
#     270         return self.update_change_target(
#     271             key, trace, update_problem, Diff.no_change(trace.get_args())
#     272         )
#
# File <@beartype(genjax._src.generative_functions.combinators.vmap.VmapCombinator.update_change_target) at 0x73a52f9a6c20>:106, in update_change_target(__beartype_object_127153717298432, __beartype_get_violation, __beartype_conf, __beartype_object_97727395876784, __beartype_object_97727395848208, __beartype_object_127153722494544, __beartype_object_97727405793760, __beartype_object_97727394042224, __beartype_object_127153717092720, __beartype_func, *args, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/generative_functions/combinators/vmap.py:255, in VmapCombinator.update_change_target(self, key, trace, update_problem, argdiffs)
#     250     return self.update_choice_map(key, trace, update_problem, argdiffs)
#     252 case ImportanceProblem(constraint) if isinstance(
#     253     constraint, ChoiceMap
#     254 ) and isinstance(trace, EmptyTrace):
# --> 255     return self.update_importance(key, constraint, argdiffs)
#     257 case _:
#     258     raise Exception(f"Not implemented problem: {update_problem}")
#
# File <@beartype(genjax._src.generative_functions.combinators.vmap.VmapCombinator.update_importance) at 0x73a52f9a6b00>:84, in update_importance(__beartype_object_127153717298432, __beartype_get_violation, __beartype_conf, __beartype_object_97727396101824, __beartype_object_127153722494544, __beartype_object_97727405793760, __beartype_object_97727394042224, __beartype_object_127153717092720, __beartype_object_97727395848208, __beartype_func, *args, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/generative_functions/combinators/vmap.py:200, in VmapCombinator.update_importance(self, key, choice_map, argdiffs)
#     190     tr, w, rd, bwd_problem = self.gen_fn.update(
#     191         key,
#     192         EmptyTrace(self.gen_fn),
#    (...)
#     196         ),
#     197     )
#     198     return tr, w, rd, ChoiceMap.entry(bwd_problem, idx)
# --> 200 (tr, w, rd, bwd_problem) = jax.vmap(
#     201     _importance, in_axes=(0, 0, None, self.in_axes)
#     202 )(sub_keys, idx_array, choice_map, primals)
#     203 w = jnp.sum(w)
#     204 retval = tr.get_retval()
#
#     [... skipping hidden 3 frame]
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/generative_functions/combinators/vmap.py:190, in VmapCombinator.update_importance.<locals>._importance(key, idx, choice_map, primals)
#     188 def _importance(key, idx, choice_map, primals):
#     189     submap = choice_map(idx)
# --> 190     tr, w, rd, bwd_problem = self.gen_fn.update(
#     191         key,
#     192         EmptyTrace(self.gen_fn),
#     193         GenericProblem(
#     194             Diff.unknown_change(primals),
#     195             ImportanceProblem(submap),
#     196         ),
#     197     )
#     198     return tr, w, rd, ChoiceMap.entry(bwd_problem, idx)
#
# File <@beartype(genjax._src.generative_functions.combinators.dimap.DimapCombinator.update) at 0x73a5482db490>:81, in update(__beartype_object_127153717298432, __beartype_get_violation, __beartype_conf, __beartype_object_97727395876784, __beartype_object_97727395848208, __beartype_object_97727396176128, __beartype_object_97727394042224, __beartype_object_127153717092720, __beartype_func, *args, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/generative_functions/combinators/dimap.py:181, in DimapCombinator.update(self, key, trace, update_problem)
#     179 match update_problem:
#     180     case GenericProblem(argdiffs, subproblem):
# --> 181         return self.update_change_target(key, trace, subproblem, argdiffs)
#     182     case _:
#     183         return self.update_change_target(
#     184             key, trace, update_problem, Diff.no_change(trace.get_args())
#     185         )
#
# File <@beartype(genjax._src.generative_functions.combinators.dimap.DimapCombinator.update_change_target) at 0x73a5482db400>:106, in update_change_target(__beartype_object_127153717298432, __beartype_get_violation, __beartype_conf, __beartype_object_97727395876784, __beartype_object_97727395848208, __beartype_object_127153722494544, __beartype_object_97727396176128, __beartype_object_97727394042224, __beartype_object_127153717092720, __beartype_func, *args, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/generative_functions/combinators/dimap.py:148, in DimapCombinator.update_change_target(self, key, trace, update_problem, argdiffs)
#     145     case EmptyTrace():
#     146         inner_trace = EmptyTrace(self.inner)
# --> 148 tr, w, inner_retdiff, bwd_problem = self.inner.update(
#     149     key, inner_trace, GenericProblem(inner_argdiffs, update_problem)
#     150 )
#     152 inner_retval_primals = Diff.tree_primal(inner_retdiff)
#     153 inner_retval_tangents = Diff.tree_tangent(inner_retdiff)
#
# File <@beartype(genjax._src.generative_functions.static.StaticGenerativeFunction.update) at 0x73a52f97a290>:81, in update(__beartype_object_127153717298432, __beartype_get_violation, __beartype_conf, __beartype_object_97727395876784, __beartype_object_97727395848208, __beartype_object_97727404449280, __beartype_object_97727394042224, __beartype_object_127153717092720, __beartype_func, *args, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/generative_functions/static.py:588, in StaticGenerativeFunction.update(self, key, trace, update_problem)
#     586 match update_problem:
#     587     case GenericProblem(argdiffs, subproblem):
# --> 588         return self.update_change_target(key, trace, subproblem, argdiffs)
#     589     case _:
#     590         return self.update(
#     591             key,
#     592             trace,
#     593             GenericProblem(Diff.no_change(trace.get_args()), update_problem),
#     594         )
#
# File <@beartype(genjax._src.generative_functions.static.StaticGenerativeFunction.update_change_target) at 0x73a52f97a200>:106, in update_change_target(__beartype_object_127153717298432, __beartype_get_violation, __beartype_conf, __beartype_object_97727395876784, __beartype_object_97727395848208, __beartype_object_127153722494544, __beartype_object_97727404449280, __beartype_object_97727394042224, __beartype_object_127153717092720, __beartype_func, *args, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/generative_functions/static.py:557, in StaticGenerativeFunction.update_change_target(self, key, trace, update_problem, argdiffs)
#     534 def update_change_target(
#     535     self,
#     536     key: PRNGKey,
#    (...)
#     539     argdiffs: Argdiffs,
#     540 ) -> tuple[StaticTrace[R], Weight, Retdiff[R], UpdateProblem]:
#     541     syntax_sugar_handled = push_trace_overload_stack(
#     542         handler_trace_with_static, self.source
#     543     )
#     544     (
#     545         (
#     546             retval_diffs,
#     547             weight,
#     548             (
#     549                 arg_primals,
#     550                 retval_primals,
#     551                 address_visitor,
#     552                 address_traces,
#     553                 score,
#     554             ),
#     555             bwd_problems,
#     556         ),
# --> 557     ) = update_transform(syntax_sugar_handled)(key, trace, update_problem, argdiffs)
#     559     def make_bwd_problem(
#     560         visitor: AddressVisitor, subproblems: list[UpdateProblem]
#     561     ) -> ChoiceMap:
#     562         addresses = visitor.get_visited()
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/generative_functions/static.py:368, in wrapper(key, previous_trace, constraints, diffs)
#     366 diff_primals = Diff.tree_primal(diffs)
#     367 diff_tangents = Diff.tree_tangent(diffs)
# --> 368 retval_diffs = incremental(source_fn)(
#     369     stateful_handler, diff_primals, diff_tangents
#     370 )
#     371 retval_primals = Diff.tree_primal(retval_diffs)
#     372 (
#     373     score,
#     374     weight,
#    (...)
#     377     bwd_problems,
#     378 ) = stateful_handler.yield_state()
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/core/interpreters/incremental.py:278, in wrapped(_stateful_handler, primals, tangents)
#     271 @functools.wraps(f)
#     272 def wrapped(
#     273     _stateful_handler: StatefulHandler | None,
#     274     primals: tuple[Any, ...],
#     275     tangents: tuple[Any, ...],
#     276 ):
#     277     interpreter = IncrementalInterpreter()
# --> 278     return interpreter.run_interpreter(
#     279         _stateful_handler,
#     280         f,
#     281         primals,
#     282         tangents,
#     283     )
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/core/interpreters/incremental.py:260, in IncrementalInterpreter.run_interpreter(self, _stateful_handler, fn, primals, tangents, **kwargs)
#     256 flat_tangents = jtu.tree_leaves(
#     257     tangents, is_leaf=lambda v: isinstance(v, ChangeTangent)
#     258 )
#     259 _jaxpr, consts = _closed_jaxpr.jaxpr, _closed_jaxpr.literals
# --> 260 flat_out = self._eval_jaxpr_forward(
#     261     _stateful_handler,
#     262     _jaxpr,
#     263     consts,
#     264     flat_primals,
#     265     flat_tangents,
#     266 )
#     267 return jtu.tree_unflatten(out_tree(), flat_out)
#
# File <@beartype(genjax._src.core.interpreters.incremental.IncrementalInterpreter._eval_jaxpr_forward) at 0x73a548239a20>:101, in _eval_jaxpr_forward(__beartype_object_97727389641808, __beartype_get_violation, __beartype_conf, __beartype_object_97727395754528, __beartype_getrandbits, __beartype_func, *args, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/core/interpreters/incremental.py:242, in IncrementalInterpreter._eval_jaxpr_forward(self, _stateful_handler, _jaxpr, consts, primals, tangents)
#     240 args = subfuns + induals
#     241 if _stateful_handler and _stateful_handler.handles(_eqn.primitive):
# --> 242     outduals = _stateful_handler.dispatch(_eqn.primitive, *args, **_params)
#     243 else:
#     244     outduals = default_propagation_rule(_eqn.primitive, *args, **_params)
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/generative_functions/static.py:220, in StaticHandler.dispatch(self, primitive, *tracers, **_params)
#     218 addr = Pytree.tree_const_unwrap(addr)
#     219 if primitive == trace_p:
# --> 220     v = self.handle_trace(addr, gen_fn, args)
#     221     return self.handle_retval(v)
#     222 else:
#
# File <@beartype(genjax._src.generative_functions.static.UpdateHandler.handle_trace) at 0x73a52f978e50>:92, in handle_trace(__beartype_getrandbits, __beartype_get_violation, __beartype_conf, __beartype_object_97727395774320, __beartype_func, *args, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/generative_functions/static.py:351, in UpdateHandler.handle_trace(self, addr, gen_fn, args)
#     349 subproblem = self.get_subproblem(addr)
#     350 self.key, sub_key = jax.random.split(self.key)
# --> 351 (tr, w, retval_diff, bwd_problem) = gen_fn.update(
#     352     sub_key, subtrace, GenericProblem(argdiffs, subproblem)
#     353 )
#     354 self.score += tr.get_score()
#     355 self.weight += w
#
# File <@beartype(genjax._src.generative_functions.distributions.distribution.Distribution.update) at 0x73a54815d750>:80, in update(__beartype_object_127153717298432, __beartype_get_violation, __beartype_conf, __beartype_object_97727395876784, __beartype_object_97727395848208, __beartype_object_97727394042224, __beartype_object_127153717092720, __beartype_func, *args, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/generative_functions/distributions/distribution.py:465, in Distribution.update(self, key, trace, update_problem)
#     463 match update_problem:
#     464     case GenericProblem(argdiffs, subproblem):
# --> 465         return self.update_change_target(key, trace, subproblem, argdiffs)
#     466     case _:
#     467         return self.update_change_target(
#     468             key, trace, update_problem, Diff.no_change(trace.get_args())
#     469         )
#
# File <@beartype(genjax._src.generative_functions.distributions.distribution.Distribution.update_change_target) at 0x73a54815d6c0>:105, in update_change_target(__beartype_object_127153717298432, __beartype_get_violation, __beartype_conf, __beartype_object_97727395876784, __beartype_object_97727395848208, __beartype_object_127153722494544, __beartype_object_97727394042224, __beartype_object_127153717092720, __beartype_func, *args, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/generative_functions/distributions/distribution.py:452, in Distribution.update_change_target(self, key, trace, update_problem, argdiffs)
#     450 case ImportanceProblem(constraint) if isinstance(trace, EmptyTrace):
#     451     primals = Diff.tree_primal(argdiffs)
# --> 452     return self.update_importance(key, constraint, primals)
#     454 case _:
#     455     raise Exception(f"Not implement fwd problem: {update_problem}.")
#
# File <@beartype(genjax._src.generative_functions.distributions.distribution.Distribution.update_importance) at 0x73a54815d2d0>:78, in update_importance(__beartype_object_127153717298432, __beartype_get_violation, __beartype_conf, __beartype_object_97727395841744, __beartype_object_97727395876784, __beartype_object_97727394042224, __beartype_object_127153717092720, __beartype_object_97727395848208, __beartype_func, *args, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/generative_functions/distributions/distribution.py:190, in Distribution.update_importance(self, key, constraint, args)
#     188 match constraint:
#     189     case ChoiceMap():
# --> 190         tr, w, bwd_problem = self.importance_choice_map(key, constraint, args)
#     191     case MaskedConstraint(flag, inner_constraint):
#     192         if staged_check(flag):
#
# File <@beartype(genjax._src.generative_functions.distributions.distribution.Distribution.importance_choice_map) at 0x73a54815d1b0>:74, in importance_choice_map(__beartype_object_127153717298432, __beartype_get_violation, __beartype_conf, __beartype_object_97727396101824, __beartype_func, *args, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/genjax/_src/generative_functions/distributions/distribution.py:144, in Distribution.importance_choice_map(self, key, chm, args)
#     141     w = self.estimate_logpdf(key, v, *args)
#     142     return (w, w, v)
# --> 144 score, w, new_v = jax.lax.cond(flag, _importance, _simulate, key, value)
#     145 tr = DistributionTrace(self, args, new_v, score)
#     146 bwd_problem = MaskedProblem(v.primal_flag(), ProjectProblem())
#
#     [... skipping hidden 3 frame]
#
# File ~/.cache/pypoetry/virtualenvs/genspn--U8-9-cv-py3.10/lib/python3.10/site-packages/jax/_src/lax/control_flow/common.py:214, in _check_tree_and_avals(what, tree1, avals1, tree2, avals2)
#     211 if not all(map(core.typematch, avals1, avals2)):
#     212   diff = tree_map(_show_diff, tree_unflatten(tree1, avals1),
#     213                   tree_unflatten(tree2, avals2))
# --> 214   raise TypeError(f"{what} must have identical types, got\n{diff}.")
#
# TypeError: true_fun and false_fun output must have identical types, got
# ('ShapedArray(float32[36])', 'DIFFERENT ShapedArray(float32[36]) vs. ShapedArray(float32[], weak_type=True)', ('ShapedArray(int32[])', 'ShapedArray(int32[36])')).

# %%
@gen
def rejuvenate_pi(assignments):
    C = 10
    cluster_counts = jnp.sum(jax.nn.one_hot(assignments, num_classes= C), axis=0)
    pi = gbd(cluster_counts) @ "pi"
    return pi

assignments, _ = tr.get_choices()["assignments", ..., "assignments"]

rejuvenate_pi.simulate(key, (assignments,))
# Out:
# <script> (()=>{ if (customElements.get('treescope-container') === undefined) { class TreescopeContainer extends HTMLElement { constructor() { super(); this.attachShadow({mode: "open"}); this.defns = {}; this.state = {}; } } customElements.define("treescope-container", TreescopeContainer); } if (customElements.get('treescope-run-here') === undefined) { class RunHere extends HTMLElement { constructor() { super() } connectedCallback() { const run = child => { const fn = new Function(child.textContent); child.textContent = ""; fn.call(this); this.remove(); }; const child = this.querySelector("script"); if (child) { run(child); } else { new MutationObserver(()=>{ run(this.querySelector("script")); }).observe(this, {childList: true}); } } } customElements.define("treescope-run-here", RunHere); } })(); </script> <treescope-container class="treescope_out_e61200986d9a46ae832917d2f4e17432" ></treescope-container> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_e61200986d9a46ae832917d2f4e17432")) .filter((elt) => !elt.dataset.setup) )[0]; root.dataset.setup = 1; const msg = document.createElement("span"); msg.style = "color: #aaaaaa; font-family: monospace; transition: opacity 0.2s; opacity: 0.0;"; msg.textContent = "(Loading...)"; root.state.loadingMsg = msg; root.shadowRoot.appendChild(msg); root.state.chain = new Promise((resolve, reject) => { const observer = new IntersectionObserver((entries) => { for (const entry of entries) { if (entry.isIntersecting) { resolve(); observer.disconnect(); return; } } }, {rootMargin: "1000px"}); window.setTimeout(() => { if (root.loadingMsg) { root.loadingMsg.style.opacity = "1.0"; } observer.observe(root); }, 0); }); root.state.deferring = false; const _insertNode = (node) => { for (let oldScript of node.querySelectorAll("script")) { let newScript = document.createElement("script"); newScript.type = oldScript.type; newScript.textContent = oldScript.textContent; oldScript.parentNode.replaceChild(newScript, oldScript); } if (root.state.loadingMsg) { root.state.loadingMsg.remove(); root.state.loadingMsg = null; } root.shadowRoot.appendChild(node); }; root.defns.insertContent = ((contentNode, compressed) => { if (compressed) { root.state.deferring = true; } if (root.state.deferring) { root.state.chain = (async () => { await root.state.chain; if (compressed) { const encoded = contentNode.textContent; const blob = new Blob([ Uint8Array.from(atob(encoded), (m) => m.codePointAt(0)) ]); const reader = blob.stream().pipeThrough( new DecompressionStream("deflate") ).pipeThrough( new TextDecoderStream("utf-8") ).getReader(); const parts = []; while (true) { const step = await reader.read(); if (step.done) { break; } parts.push(step.value); } const tpl = document.createElement('template'); tpl.innerHTML = parts.join(""); _insertNode(tpl.content); } else { _insertNode(contentNode.content); } })(); } else { _insertNode(contentNode.content); } }); </script></treescope-run-here><div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_e61200986d9a46ae832917d2f4e17432")) .filter((elt) => !elt.dataset['step0']) )[0]; root.dataset['step0'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# <div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_e61200986d9a46ae832917d2f4e17432")) .filter((elt) => !elt.dataset['step1']) )[0]; root.dataset['step1'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# StaticTrace(...)

# %%
@gen
def rejuvenate_parameters(assignments, data):
    C = 10
    n_features = 20
    # update posterior of hyperparameters
    one_hot_x = jax.nn.one_hot(data, num_classes=n_features)
    counts = jax.ops.segment_sum(one_hot_x, assignments, num_segments=C)
    concentration = jnp.ones((C, data.shape[1], n_features)) + counts
    parameters = dirichlet(concentration) @ "parameters"
    return parameters

assignments, _ = tr.get_choices()["assignments", ..., "assignments"]
data = jax.random.randint(key, (100, 36), minval=0, maxval=19)
rejuvenate_parameters.simulate(key, (assignments, data))
# Out:
# <script> (()=>{ if (customElements.get('treescope-container') === undefined) { class TreescopeContainer extends HTMLElement { constructor() { super(); this.attachShadow({mode: "open"}); this.defns = {}; this.state = {}; } } customElements.define("treescope-container", TreescopeContainer); } if (customElements.get('treescope-run-here') === undefined) { class RunHere extends HTMLElement { constructor() { super() } connectedCallback() { const run = child => { const fn = new Function(child.textContent); child.textContent = ""; fn.call(this); this.remove(); }; const child = this.querySelector("script"); if (child) { run(child); } else { new MutationObserver(()=>{ run(this.querySelector("script")); }).observe(this, {childList: true}); } } } customElements.define("treescope-run-here", RunHere); } })(); </script> <treescope-container class="treescope_out_1fc6ef7ae928447dbd54e4a03b134a05" ></treescope-container> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_1fc6ef7ae928447dbd54e4a03b134a05")) .filter((elt) => !elt.dataset.setup) )[0]; root.dataset.setup = 1; const msg = document.createElement("span"); msg.style = "color: #aaaaaa; font-family: monospace; transition: opacity 0.2s; opacity: 0.0;"; msg.textContent = "(Loading...)"; root.state.loadingMsg = msg; root.shadowRoot.appendChild(msg); root.state.chain = new Promise((resolve, reject) => { const observer = new IntersectionObserver((entries) => { for (const entry of entries) { if (entry.isIntersecting) { resolve(); observer.disconnect(); return; } } }, {rootMargin: "1000px"}); window.setTimeout(() => { if (root.loadingMsg) { root.loadingMsg.style.opacity = "1.0"; } observer.observe(root); }, 0); }); root.state.deferring = false; const _insertNode = (node) => { for (let oldScript of node.querySelectorAll("script")) { let newScript = document.createElement("script"); newScript.type = oldScript.type; newScript.textContent = oldScript.textContent; oldScript.parentNode.replaceChild(newScript, oldScript); } if (root.state.loadingMsg) { root.state.loadingMsg.remove(); root.state.loadingMsg = null; } root.shadowRoot.appendChild(node); }; root.defns.insertContent = ((contentNode, compressed) => { if (compressed) { root.state.deferring = true; } if (root.state.deferring) { root.state.chain = (async () => { await root.state.chain; if (compressed) { const encoded = contentNode.textContent; const blob = new Blob([ Uint8Array.from(atob(encoded), (m) => m.codePointAt(0)) ]); const reader = blob.stream().pipeThrough( new DecompressionStream("deflate") ).pipeThrough( new TextDecoderStream("utf-8") ).getReader(); const parts = []; while (true) { const step = await reader.read(); if (step.done) { break; } parts.push(step.value); } const tpl = document.createElement('template'); tpl.innerHTML = parts.join(""); _insertNode(tpl.content); } else { _insertNode(contentNode.content); } })(); } else { _insertNode(contentNode.content); } }); </script></treescope-run-here><div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_1fc6ef7ae928447dbd54e4a03b134a05")) .filter((elt) => !elt.dataset['step0']) )[0]; root.dataset['step0'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# <div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_1fc6ef7ae928447dbd54e4a03b134a05")) .filter((elt) => !elt.dataset['step1']) )[0]; root.dataset['step1'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# StaticTrace(...)

# %%
@gen
def rejuvenate_parameters(assignments, data):
    C = 10
    n_features = 20
    # update posterior of hyperparameters
    one_hot_x = jax.nn.one_hot(data, num_classes=n_features)
    counts = jax.ops.segment_sum(one_hot_x, assignments, num_segments=C)
    concentration = jnp.ones((C, data.shape[1], n_features)) + counts
    parameters = dirichlet(concentration) @ "parameters"
    return parameters

assignments, _ = tr.get_choices()["assignments", ..., "assignments"]
data = jax.random.randint(key, (100, 36), minval=0, maxval=19)
rejuvenate_parameters.simulate(key, (assignments, data))
# Out:
# <script> (()=>{ if (customElements.get('treescope-container') === undefined) { class TreescopeContainer extends HTMLElement { constructor() { super(); this.attachShadow({mode: "open"}); this.defns = {}; this.state = {}; } } customElements.define("treescope-container", TreescopeContainer); } if (customElements.get('treescope-run-here') === undefined) { class RunHere extends HTMLElement { constructor() { super() } connectedCallback() { const run = child => { const fn = new Function(child.textContent); child.textContent = ""; fn.call(this); this.remove(); }; const child = this.querySelector("script"); if (child) { run(child); } else { new MutationObserver(()=>{ run(this.querySelector("script")); }).observe(this, {childList: true}); } } } customElements.define("treescope-run-here", RunHere); } })(); </script> <treescope-container class="treescope_out_d85d776dda374ff9b705788ef4793be3" ></treescope-container> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_d85d776dda374ff9b705788ef4793be3")) .filter((elt) => !elt.dataset.setup) )[0]; root.dataset.setup = 1; const msg = document.createElement("span"); msg.style = "color: #aaaaaa; font-family: monospace; transition: opacity 0.2s; opacity: 0.0;"; msg.textContent = "(Loading...)"; root.state.loadingMsg = msg; root.shadowRoot.appendChild(msg); root.state.chain = new Promise((resolve, reject) => { const observer = new IntersectionObserver((entries) => { for (const entry of entries) { if (entry.isIntersecting) { resolve(); observer.disconnect(); return; } } }, {rootMargin: "1000px"}); window.setTimeout(() => { if (root.loadingMsg) { root.loadingMsg.style.opacity = "1.0"; } observer.observe(root); }, 0); }); root.state.deferring = false; const _insertNode = (node) => { for (let oldScript of node.querySelectorAll("script")) { let newScript = document.createElement("script"); newScript.type = oldScript.type; newScript.textContent = oldScript.textContent; oldScript.parentNode.replaceChild(newScript, oldScript); } if (root.state.loadingMsg) { root.state.loadingMsg.remove(); root.state.loadingMsg = null; } root.shadowRoot.appendChild(node); }; root.defns.insertContent = ((contentNode, compressed) => { if (compressed) { root.state.deferring = true; } if (root.state.deferring) { root.state.chain = (async () => { await root.state.chain; if (compressed) { const encoded = contentNode.textContent; const blob = new Blob([ Uint8Array.from(atob(encoded), (m) => m.codePointAt(0)) ]); const reader = blob.stream().pipeThrough( new DecompressionStream("deflate") ).pipeThrough( new TextDecoderStream("utf-8") ).getReader(); const parts = []; while (true) { const step = await reader.read(); if (step.done) { break; } parts.push(step.value); } const tpl = document.createElement('template'); tpl.innerHTML = parts.join(""); _insertNode(tpl.content); } else { _insertNode(contentNode.content); } })(); } else { _insertNode(contentNode.content); } }); </script></treescope-run-here><div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_d85d776dda374ff9b705788ef4793be3")) .filter((elt) => !elt.dataset['step0']) )[0]; root.dataset['step0'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# <div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_d85d776dda374ff9b705788ef4793be3")) .filter((elt) => !elt.dataset['step1']) )[0]; root.dataset['step1'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# StaticTrace(...)

# %%
@Pytree.dataclass
class ConjugatePrior(genjax.inference.Algorithm):
    def random_weighted(self, target: Target):
        # print(target)
        return jnp.array(1.0), target
    def estimate_logpdf(self, x, target: Target):
        return jnp.array(1.0)
    def estimate_normalizing_constant(self, target: Target):
        super().estimate_normalizing_constant(target)
    def estimate_reciprocal_normalizing_constant(self, key, target, latent_choices, w):
        return super().estimate_reciprocal_normalizing_constant(key, target, latent_choices, w)

conj = ConjugatePrior()

@genjax.gen
def model():
    x = genjax.normal(0.0, 1.0) @ "x"
    y = genjax.normal(x, 1.0) @ "y"
    return x

target = Target(model, (), C["y"].set(3.0))
conj.random_weighted(target)
# Out:
# <script> (()=>{ if (customElements.get('treescope-container') === undefined) { class TreescopeContainer extends HTMLElement { constructor() { super(); this.attachShadow({mode: "open"}); this.defns = {}; this.state = {}; } } customElements.define("treescope-container", TreescopeContainer); } if (customElements.get('treescope-run-here') === undefined) { class RunHere extends HTMLElement { constructor() { super() } connectedCallback() { const run = child => { const fn = new Function(child.textContent); child.textContent = ""; fn.call(this); this.remove(); }; const child = this.querySelector("script"); if (child) { run(child); } else { new MutationObserver(()=>{ run(this.querySelector("script")); }).observe(this, {childList: true}); } } } customElements.define("treescope-run-here", RunHere); } })(); </script> <treescope-container class="treescope_out_23146548dcd54c1ea180544c2ec862c9" ></treescope-container> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_23146548dcd54c1ea180544c2ec862c9")) .filter((elt) => !elt.dataset.setup) )[0]; root.dataset.setup = 1; const msg = document.createElement("span"); msg.style = "color: #aaaaaa; font-family: monospace; transition: opacity 0.2s; opacity: 0.0;"; msg.textContent = "(Loading...)"; root.state.loadingMsg = msg; root.shadowRoot.appendChild(msg); root.state.chain = new Promise((resolve, reject) => { const observer = new IntersectionObserver((entries) => { for (const entry of entries) { if (entry.isIntersecting) { resolve(); observer.disconnect(); return; } } }, {rootMargin: "1000px"}); window.setTimeout(() => { if (root.loadingMsg) { root.loadingMsg.style.opacity = "1.0"; } observer.observe(root); }, 0); }); root.state.deferring = false; const _insertNode = (node) => { for (let oldScript of node.querySelectorAll("script")) { let newScript = document.createElement("script"); newScript.type = oldScript.type; newScript.textContent = oldScript.textContent; oldScript.parentNode.replaceChild(newScript, oldScript); } if (root.state.loadingMsg) { root.state.loadingMsg.remove(); root.state.loadingMsg = null; } root.shadowRoot.appendChild(node); }; root.defns.insertContent = ((contentNode, compressed) => { if (compressed) { root.state.deferring = true; } if (root.state.deferring) { root.state.chain = (async () => { await root.state.chain; if (compressed) { const encoded = contentNode.textContent; const blob = new Blob([ Uint8Array.from(atob(encoded), (m) => m.codePointAt(0)) ]); const reader = blob.stream().pipeThrough( new DecompressionStream("deflate") ).pipeThrough( new TextDecoderStream("utf-8") ).getReader(); const parts = []; while (true) { const step = await reader.read(); if (step.done) { break; } parts.push(step.value); } const tpl = document.createElement('template'); tpl.innerHTML = parts.join(""); _insertNode(tpl.content); } else { _insertNode(contentNode.content); } })(); } else { _insertNode(contentNode.content); } }); </script></treescope-run-here><div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_23146548dcd54c1ea180544c2ec862c9")) .filter((elt) => !elt.dataset['step0']) )[0]; root.dataset['step0'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# <div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_23146548dcd54c1ea180544c2ec862c9")) .filter((elt) => !elt.dataset['step1']) )[0]; root.dataset['step1'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# (<jax.Array(1., dtype=float32, weak_type=True)>, Target(...))

# %%
import genspn.smc
@gen
def rejuvenate_assignments(label_logp):
    C = 10
    n_features = 20
    # genjax evaluate

    # assignments = jax.random.categorical(key, log_score, axis=-1).astype(int)
    # categorical()
    # return assignments

assignments, _ = tr.get_choices()["assignments", ..., "assignments"]
parameters = tr.get_choices()["parameters"]
mask = genspn.smc.make_log_likelihood_mask(assignments, 10)
# categorical.estimate_logpdf(key, parameters)
# logprobs = jax.vmap(jax.scipy.stats.dirichlet.logpdf)(jnp.exp(x.logprobs), dist.alpha)
# return jnp.sum(logprobs)
# log_likelihoods = jax.vmap(jax.vmap(genspn.distributions.logpdf, in_axes=(0, None)), in_axes=(None, 0))(parameters, data)
# log_likelihoods = log_likelihoods + mask
# log_score = log_likelihoods + jnp.log(pi)
# data = jax.random.randint(key, (100, 36), minval=0, maxval=19)
# rejuvenate_parameters.simulate(key, (assignments, data))
# Out:
# 0.99999994

# %%
train, test = load_huggingface("AutoML/soybean")
# Out:
# shape: (307, 36)
# ┌────────────────┬──────┬─────────────┬────────┬───┬───────────────┬───────────┬────────────┬──────┐
# │ class          ┆ date ┆ plant_stand ┆ precip ┆ … ┆ seed_discolor ┆ seed_size ┆ shriveling ┆ root │
# │ ---            ┆ ---  ┆ ---         ┆ ---    ┆   ┆ ---           ┆ ---       ┆ ---        ┆ ---  │
# │ str            ┆ str  ┆ str         ┆ str    ┆   ┆ str           ┆ str       ┆ str        ┆ str  │
# ╞════════════════╪══════╪═════════════╪════════╪═══╪═══════════════╪═══════════╪════════════╪══════╡
# │ phytophthora_r ┆ 2    ┆ 1           ┆ 1      ┆ … ┆ null          ┆ null      ┆ null       ┆ 1    │
# │ ot             ┆      ┆             ┆        ┆   ┆               ┆           ┆            ┆      │
# │ frog_eye_leaf_ ┆ 3    ┆ 0           ┆ 2      ┆ … ┆ 0             ┆ 0         ┆ 0          ┆ 0    │
# │ spot           ┆      ┆             ┆        ┆   ┆               ┆           ┆            ┆      │
# │ phytophthora_r ┆ 1    ┆ 1           ┆ 2      ┆ … ┆ 0             ┆ 0         ┆ 0          ┆ 0    │
# │ ot             ┆      ┆             ┆        ┆   ┆               ┆           ┆            ┆      │
# │ brown_spot     ┆ 2    ┆ 0           ┆ 2      ┆ … ┆ 0             ┆ 0         ┆ 0          ┆ 0    │
# │ brown_spot     ┆ 3    ┆ 1           ┆ 2      ┆ … ┆ 0             ┆ 0         ┆ 0          ┆ 0    │
# │ …              ┆ …    ┆ …           ┆ …      ┆ … ┆ …             ┆ …         ┆ …          ┆ …    │
# │ frog_eye_leaf_ ┆ 5    ┆ 0           ┆ 2      ┆ … ┆ 0             ┆ 0         ┆ 0          ┆ 0    │
# │ spot           ┆      ┆             ┆        ┆   ┆               ┆           ┆            ┆      │
# │ downy_mildew   ┆ 5    ┆ 1           ┆ 2      ┆ … ┆ 0             ┆ 0         ┆ 0          ┆ 0    │
# │ brown_spot     ┆ 3    ┆ 1           ┆ 2      ┆ … ┆ 0             ┆ 0         ┆ 0          ┆ 0    │
# │ purple_seed_st ┆ 3    ┆ 0           ┆ 2      ┆ … ┆ 1             ┆ 0         ┆ 0          ┆ 0    │
# │ ain            ┆      ┆             ┆        ┆   ┆               ┆           ┆            ┆      │
# │ alternarialeaf ┆ 5    ┆ 1           ┆ 2      ┆ … ┆ 0             ┆ 0         ┆ 0          ┆ 0    │
# │ _spot          ┆      ┆             ┆        ┆   ┆               ┆           ┆            ┆      │
# └────────────────┴──────┴─────────────┴────────┴───┴───────────────┴───────────┴────────────┴──────┘
# /home/ubuntu/docs/GenSPN/src/genspn/io.py:22: CategoricalRemappingWarning: Local categoricals have different encodings, expensive re-encoding is done to perform this merge operation. Consider using a StringCache or an Enum type if the categories are known in advance
#   df = df.cast(pl.Categorical)

# %%
def f(key, logp):
    return jax.random.categorical(key, logp)

key = jax.random.PRNGKey(0)
logp = jnp.ones((10000, 10))
f_jitted = jax.jit(f)
f_jitted(key, logp)
start = time.process_time()
f_jitted(key, logp).block_until_ready()
print((time.process_time() - start)*1000)
# Out:
# 0.3081829999995733
